# %%
import os
import numpy as np
import pandas as pd

# %%
os.getcwd()  # Location of current working directory
# Out:
# 'C:\\Users\\Archit\\ATraining\\PGA15\\week03'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'mbox_short.txt',
#  'Packages.ipynb',
#  'Pandas.ipynb',
#  'Practice01.ipynb',
#  'Untitled.ipynb']

# %%
os.chdir("D:\\Training\\Imarticus\\PGA\\PGA15\\week3")

# %%
os.getcwd()
# Out:
# 'D:\\Training\\Imarticus\\PGA\\PGA15\\week3'

# %%
os.listdir()
# Out:
# ['car_done.csv', 'Car_sales.csv', 'Churn_Modelling.csv']

# %%
churn=pd.read_csv('Churn_Modelling.csv')

# %%
churn
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
churn.head(4)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0

# %%
churn.tail(3)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
churn.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
churn.shape
# Out:
# (10000, 14)

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
car=pd.read_csv("car_done.csv")

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              157 non-null    int64
#  1   Manufacturer            157 non-null    object
#  2   Model                   157 non-null    object
#  3   Sales_in_thousands      157 non-null    float64
#  4   four_year_resale_value  121 non-null    float64
#  5   Vehicle_type            157 non-null    object
#  6   Price_in_thousands      155 non-null    float64
#  7   Engine_size             156 non-null    float64
#  8   Horsepower              156 non-null    float64
#  9   Wheelbase               156 non-null    float64
#  10  Width                   156 non-null    float64
#  11  Length                  156 non-null    float64
#  12  Curb_weight             155 non-null    float64
#  13  Fuel_capacity           156 non-null    float64
# ...

# %% [markdown]
# ## New columns creation

# %%
car
# Out:
#      Unnamed: 0 Manufacturer    Model  Sales_in_thousands  \
# 0             0        Acura  Integra              16.919
# 1             1        Acura       TL              39.384
# 2             2        Acura       CL              14.114
# 3             3        Acura       RL               8.588
# 4             4         Audi       A4              20.397
# ..          ...          ...      ...                 ...
# 152         152        Volvo      V40               3.545
# 153         153        Volvo      S70              15.245
# 154         154        Volvo      V70              17.531
# 155         155        Volvo      C70               3.493
# 156         156        Volvo      S80              18.969
#
#      four_year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                    16.360    Passenger               21.50          1.8
# 1                    19.875    Passenger               28.40          3.2
# ...

# %%
car.columns
# Out:
# Index(['Unnamed: 0', 'Manufacturer', 'Model', 'Sales_in_thousands',
#        'four_year_resale_value', 'Vehicle_type', 'Price_in_thousands',
#        'Engine_size', 'Horsepower', 'Wheelbase', 'Width', 'Length',
#        'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency', 'Latest_Launch',
#        'Power_perf_factor'],
#       dtype='object')

# %%
car["newcol1"]=0

# %%
car
# Out:
#      Unnamed: 0 Manufacturer    Model  Sales_in_thousands  \
# 0             0        Acura  Integra              16.919
# 1             1        Acura       TL              39.384
# 2             2        Acura       CL              14.114
# 3             3        Acura       RL               8.588
# 4             4         Audi       A4              20.397
# ..          ...          ...      ...                 ...
# 152         152        Volvo      V40               3.545
# 153         153        Volvo      S70              15.245
# 154         154        Volvo      V70              17.531
# 155         155        Volvo      C70               3.493
# 156         156        Volvo      S80              18.969
#
#      four_year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                    16.360    Passenger               21.50          1.8
# 1                    19.875    Passenger               28.40          3.2
# ...

# %%
car["newcol2"]=np.NaN  # Missing Value

# %%
# drop a column 
car.drop(["newcol2"],axis=1)
# Out:
#      Unnamed: 0 Manufacturer    Model  Sales_in_thousands  \
# 0             0        Acura  Integra              16.919
# 1             1        Acura       TL              39.384
# 2             2        Acura       CL              14.114
# 3             3        Acura       RL               8.588
# 4             4         Audi       A4              20.397
# ..          ...          ...      ...                 ...
# 152         152        Volvo      V40               3.545
# 153         153        Volvo      S70              15.245
# 154         154        Volvo      V70              17.531
# 155         155        Volvo      C70               3.493
# 156         156        Volvo      S80              18.969
#
#      four_year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                    16.360    Passenger               21.50          1.8
# 1                    19.875    Passenger               28.40          3.2
# ...

# %%
car
# Out:
#      Unnamed: 0 Manufacturer    Model  Sales_in_thousands  \
# 0             0        Acura  Integra              16.919
# 1             1        Acura       TL              39.384
# 2             2        Acura       CL              14.114
# 3             3        Acura       RL               8.588
# 4             4         Audi       A4              20.397
# ..          ...          ...      ...                 ...
# 152         152        Volvo      V40               3.545
# 153         153        Volvo      S70              15.245
# 154         154        Volvo      V70              17.531
# 155         155        Volvo      C70               3.493
# 156         156        Volvo      S80              18.969
#
#      four_year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                    16.360    Passenger               21.50          1.8
# 1                    19.875    Passenger               28.40          3.2
# ...

# %%
car
# Out:
#      Unnamed: 0 Manufacturer    Model  Sales_in_thousands  \
# 0             0        Acura  Integra              16.919
# 1             1        Acura       TL              39.384
# 2             2        Acura       CL              14.114
# 3             3        Acura       RL               8.588
# 4             4         Audi       A4              20.397
# ..          ...          ...      ...                 ...
# 152         152        Volvo      V40               3.545
# 153         153        Volvo      S70              15.245
# 154         154        Volvo      V70              17.531
# 155         155        Volvo      C70               3.493
# 156         156        Volvo      S80              18.969
#
#      four_year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                    16.360    Passenger               21.50          1.8
# 1                    19.875    Passenger               28.40          3.2
# ...

# %%
car["Area_car"]=car["Length"]*car["Width"]

# %%
car
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger                21.5          1.8       140.0      101.2
# ...

# %%
car["Car_cat"]=np.where(car["Price_in_thousands"] >20, "CostlyCar", "LowCostCar")

# %%
car["Car_cat"].value_counts()
# Out:
# CostlyCar     97
# LowCostCar    60
# Name: Car_cat, dtype: int64

# %%
def gg(x):
    if x<10:
        return "Poor"
    elif x>=10 and x<30:
        return "Middle"
    else:
        return "High"

# %%
car["Sale_cat"]=car["Sales_in_thousands"].apply(gg)

# %%
car["Sale_cat"].value_counts()
# Out:
# High      78
# Middle    48
# Poor      31
# Name: Sale_cat, dtype: int64

# %%
car[["Sales_in_thousands","Sale_cat"]]
# Out:
#      Sales_in_thousands Sale_cat
# 0                16.919   Middle
# 1                39.384     High
# 2                14.114   Middle
# 3                 8.588     Poor
# 4                20.397   Middle
# ..                  ...      ...
# 152               3.545     Poor
# 153              15.245   Middle
# 154              17.531   Middle
# 155               3.493     Poor
# 156              18.969   Middle
#
# [157 rows x 2 columns]

# %%
car
# Out:
#      Unnamed: 0 Manufacturer    Model  Sales_in_thousands  \
# 0             0        Acura  Integra              16.919
# 1             1        Acura       TL              39.384
# 2             2        Acura       CL              14.114
# 3             3        Acura       RL               8.588
# 4             4         Audi       A4              20.397
# ..          ...          ...      ...                 ...
# 152         152        Volvo      V40               3.545
# 153         153        Volvo      S70              15.245
# 154         154        Volvo      V70              17.531
# 155         155        Volvo      C70               3.493
# 156         156        Volvo      S80              18.969
#
#      four_year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                    16.360    Passenger               21.50          1.8
# 1                    19.875    Passenger               28.40          3.2
# ...

# %% [markdown]
# ### Subsetting of data

# %%
# Columns subsetting

# %%
car["Sales_in_thousands"]
# Out:
# 0      16.919
# 1      39.384
# 2      14.114
# 3       8.588
# 4      20.397
#         ...
# 152     3.545
# 153    15.245
# 154    17.531
# 155     3.493
# 156    18.969
# Name: Sales_in_thousands, Length: 157, dtype: float64

# %%
car.Sales_in_thousands
# Out:
# 0      16.919
# 1      39.384
# 2      14.114
# 3       8.588
# 4      20.397
#         ...
# 152     3.545
# 153    15.245
# 154    17.531
# 155     3.493
# 156    18.969
# Name: Sales_in_thousands, Length: 157, dtype: float64

# %%
car[["Sales_in_thousands"]]
# Out:
#      Sales_in_thousands
# 0                16.919
# 1                39.384
# 2                14.114
# 3                 8.588
# 4                20.397
# ..                  ...
# 152               3.545
# 153              15.245
# 154              17.531
# 155               3.493
# 156              18.969
#
# [157 rows x 1 columns]

# %%
car[["Sales_in_thousands", "Price_in_thousands", "Engine_size"]]
# Out:
#      Sales_in_thousands  Price_in_thousands  Engine_size
# 0                16.919                21.5          1.8
# 1                39.384                28.4          3.2
# 2                14.114                 NaN          3.2
# 3                 8.588                 NaN          3.5
# 4                20.397                 NaN          1.8
# ..                  ...                 ...          ...
# 152               3.545                24.4          1.9
# 153              15.245                27.5          2.4
# 154              17.531                28.8          2.4
# 155               3.493                45.5          2.3
# 156              18.969                36.0          2.9
#
# [157 rows x 3 columns]

# %%
# car.loc  #  It uses label as an input 
# car.iloc #  It uses index as an input

# %%
car
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger                21.5          1.8       140.0      101.2
# ...

# %%
car.loc[10:15,["Sales_in_thousands"]]
# Out:
#     Sales_in_thousands
# 10              91.561
# 11              39.350
# 12              27.851
# 13              83.257
# 14              63.729
# 15              15.943

# %%
car.loc[10:15,["Sales_in_thousands", "Price_in_thousands"]]
# Out:
#     Sales_in_thousands  Price_in_thousands
# 10              91.561              21.975
# 11              39.350              25.300
# 12              27.851              31.965
# 13              83.257              27.885
# 14              63.729              39.895
# 15              15.943              44.475

# %%
car.index
# Out:
# RangeIndex(start=0, stop=157, step=1)

# %%
car1=car.set_index("Manufacturer")

# %%
car1
# Out:
#                 Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# Manufacturer
# Acura         Integra              16.919               16.360    Passenger
# Acura              TL              39.384               19.875    Passenger
# Acura              CL              14.114               18.225    Passenger
# Acura              RL               8.588               29.725    Passenger
# Audi               A4              20.397               22.255    Passenger
# ...               ...                 ...                  ...          ...
# Volvo             V40               3.545                  NaN    Passenger
# Volvo             S70              15.245                  NaN    Passenger
# Volvo             V70              17.531                  NaN    Passenger
# Volvo             C70               3.493                  NaN    Passenger
# Volvo             S80              18.969                  NaN    Passenger
#
# ...

# %%
car
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger                21.5          1.8       140.0      101.2
# ...

# %%
car.set_index("Manufacturer", inplace=True)  # action and replacing the original data

# %%
car
# Out:
#                 Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# Manufacturer
# Acura         Integra              16.919               16.360    Passenger
# Acura              TL              39.384               19.875    Passenger
# Acura              CL              14.114               18.225    Passenger
# Acura              RL               8.588               29.725    Passenger
# Audi               A4              20.397               22.255    Passenger
# ...               ...                 ...                  ...          ...
# Volvo             V40               3.545                  NaN    Passenger
# Volvo             S70              15.245                  NaN    Passenger
# Volvo             V70              17.531                  NaN    Passenger
# Volvo             C70               3.493                  NaN    Passenger
# Volvo             S80              18.969                  NaN    Passenger
#
# ...

# %%
car.loc["Volvo",["Sales_in_thousands"]]
# Out:
#               Sales_in_thousands
# Manufacturer
# Volvo                     16.957
# Volvo                      3.545
# Volvo                     15.245
# Volvo                     17.531
# Volvo                      3.493
# Volvo                     18.969

# %%
car.loc[["Volvo", "Audi"],["Sales_in_thousands", "Engine_size"]]
# Out:
#               Sales_in_thousands  Engine_size
# Manufacturer
# Volvo                     16.957          1.9
# Volvo                      3.545          1.9
# Volvo                     15.245          2.4
# Volvo                     17.531          2.4
# Volvo                      3.493          2.3
# Volvo                     18.969          2.9
# Audi                      20.397          1.8
# Audi                      18.780          2.8
# Audi                       1.380          4.2

# %%
car.iloc[10:15,10:14]
# Out:
#               Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch
# Manufacturer
# Buick               3.368           17.5             25.0    11-02-2011
# Buick               3.543           17.5             23.0    09-03-2011
# Buick               3.778           18.5             24.0     3/23/2012
# Buick               3.591           17.5             25.0     7/23/2011
# Cadillac            3.978           18.5             22.0     2/23/2012

# %%
car.iloc[10:15,[2,5,10]]
# Out:
#               __year_resale_value  Engine_size  Curb_weight
# Manufacturer
# Buick                      12.475          3.1        3.368
# Buick                      13.740          3.8        3.543
# Buick                      20.190          3.8        3.778
# Buick                      13.360          3.8        3.591
# Cadillac                   22.525          4.6        3.978

# %%
car.iloc[[3,6,100],[2,5,10]]
# Out:
#               __year_resale_value  Engine_size  Curb_weight
# Manufacturer
# Acura                      29.725          3.5        3.850
# Audi                          NaN          4.2        3.902
# Mercedes-B                    NaN          3.2        4.387

# %%
car.reset_index(inplace=True)

# %%
car
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger                21.5          1.8       140.0      101.2
# ...

# %%
# Rows and Columns : index , labels

# %% [markdown]
# ### Conditional Subsetting

# %%
car["Manufacturer"].value_counts()  # It gives freq distribution
# Out:
# Dodge         11
# Ford          11
# Chevrolet      9
# Mercedes-B     9
# Toyota         9
# Mitsubishi     7
# Nissan         7
# Chrysler       7
# Oldsmobile     6
# Lexus          6
# Mercury        6
# Volkswagen     6
# Pontiac        6
# Volvo          6
# Saturn         5
# Honda          5
# Cadillac       5
# Buick          4
# Plymouth       4
# Acura          4
# Audi           3
# Hyundai        3
# Jeep           3
# BMW            3
# Porsche        3
# Lincoln        3
# Subaru         2
# Saab           2
# Jaguar         1
# Infiniti       1
# Name: Manufacturer, dtype: int64

# %%
# car[]
car[car["Manufacturer"]=="BMW"]
# Out:
#   Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 7          BMW  323i              19.747                  NaN    Passenger
# 8          BMW  328i               9.231               28.675    Passenger
# 9          BMW  528i              17.527               36.125    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  ...  \
# 7               26.99          2.5       170.0      107.3   68.4  ...
# 8               33.40          2.8       193.0      107.3   68.5  ...
# 9               38.90          2.8       193.0      111.4   70.9  ...
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency  Latest_Launch  \
# 7        3.179           16.6             26.0      6/28/2011
# 8        3.197           16.6             24.0      1/29/2012
# 9        3.472           18.5             25.0     04-04-2011
#
#   Power_perf_factor  newcol1  newcol2  Area_car    Car_cat Sale_cat
# ...

# %%
car[car["Sales_in_thousands"]<=5]
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 6           Audi              A8               1.380                  NaN
# 36         Dodge         Avenger               4.734               12.545
# 39         Dodge           Viper               0.916               58.470
# 72         Lexus           GS400               3.334                  NaN
# 83    Mitsubishi          3000GT               0.110               20.940
# 95    Mercedes-B        SL-Class               3.311               58.600
# 97    Mercedes-B          SLK230               1.526                  NaN
# 99    Mercedes-B           CL500               0.954                  NaN
# 108   Oldsmobile         Cutlass               1.112               11.240
# 117     Plymouth         Prowler               1.872                  NaN
# 125      Porsche   Carrera Coupe               1.280               60.625
# 126      Porsche  Carrera Cabrio               1.866               67.550
# ...

# %%
car[(car["Sales_in_thousands"]<=5) & (car["Manufacturer"]=="Volvo")]
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 152        Volvo   V40               3.545                  NaN    Passenger
# 155        Volvo   C70               3.493                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  ...  \
# 152                24.4          1.9       160.0      100.5   67.6  ...
# 155                45.5          2.3       236.0      104.9   71.5  ...
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency  Latest_Launch  \
# 152        3.042           15.8             25.0      9/21/2011
# 155        3.601           18.5             23.0      4/26/2011
#
#     Power_perf_factor  newcol1  newcol2  Area_car    Car_cat Sale_cat
# 152         66.498812        0      NaN  11938.16  CostlyCar     Poor
# 155        101.623357        0      NaN  13277.55  CostlyCar     Poor
#
# [2 rows x 21 columns]

# %%
car[car["Horsepower"]>=300].shape[0]
# Out:
# 9

# %%
# Name those manufacturere where sales <10 and price >50 
car[(car["Sales_in_thousands"]<10) & (car["Price_in_thousands"]>50)]["Manufacturer"].unique()
# Out:
# array(['Audi', 'Dodge', 'Lexus', 'Mercedes-B', 'Porsche', 'Toyota'],
#       dtype=object)

# %%
car["Vehicle_type"].value_counts()
# Out:
# Passenger    116
# Car           41
# Name: Vehicle_type, dtype: int64

# %%
car.loc[car["Sales_in_thousands"]<10,["Manufacturer", "Sales_in_thousands"]]
# Out:
#     Manufacturer  Sales_in_thousands
# 3          Acura               8.588
# 6           Audi               1.380
# 8            BMW               9.231
# 16      Cadillac               6.536
# 28      Chrysler               7.854
# 36         Dodge               4.734
# 39         Dodge               0.916
# 72         Lexus               3.334
# 73         Lexus               6.375
# 74         Lexus               9.126
# 82    Mitsubishi               5.711
# 83    Mitsubishi               0.110
# 95    Mercedes-B               3.311
# 96    Mercedes-B               7.998
# 97    Mercedes-B               1.526
# 99    Mercedes-B               0.954
# 108   Oldsmobile               1.112
# 115     Plymouth               5.240
# 117     Plymouth               1.872
# 124      Porsche               8.982
# 125      Porsche               1.280
# 126      Porsche               1.866
# 127         Saab               9.191
# 131       Saturn               5.223
# ...

# %%
cond1=car["Sales_in_thousands"]<10
cond2=car["Price_in_thousands"]>60
cond3=car["Vehicle_type"]=="Passenger"

car.loc[cond1 | cond2 ,["Manufacturer", "Sales_in_thousands"]]
# Out:
#     Manufacturer  Sales_in_thousands
# 3          Acura               8.588
# 6           Audi               1.380
# 8            BMW               9.231
# 16      Cadillac               6.536
# 28      Chrysler               7.854
# 36         Dodge               4.734
# 39         Dodge               0.916
# 72         Lexus               3.334
# 73         Lexus               6.375
# 74         Lexus               9.126
# 82    Mitsubishi               5.711
# 83    Mitsubishi               0.110
# 94    Mercedes-B              16.774
# 95    Mercedes-B               3.311
# 96    Mercedes-B               7.998
# 97    Mercedes-B               1.526
# 99    Mercedes-B               0.954
# 108   Oldsmobile               1.112
# 115     Plymouth               5.240
# 117     Plymouth               1.872
# 124      Porsche               8.982
# 125      Porsche               1.280
# 126      Porsche               1.866
# 127         Saab               9.191
# ...

# %%
car.loc[(car["Sales_in_thousands"]<10) & (car["Price_in_thousands"]>60) & (car["Vehicle_type"]=="Passenger"),["Manufacturer", "Sales_in_thousands"]]
# Out:
#     Manufacturer  Sales_in_thousands
# 6           Audi               1.380
# 39         Dodge               0.916
# 95    Mercedes-B               3.311
# 99    Mercedes-B               0.954
# 125      Porsche               1.280
# 126      Porsche               1.866

# %% [markdown]
# ### Sorting of data

# %%
car.sort_values(by=["Sales_in_thousands"], ascending=False)
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 56          Ford       F-Series             540.561               15.075
# 52          Ford       Explorer             276.747               16.640
# 137       Toyota          Camry             247.994               13.245
# 49          Ford         Taurus             245.815               10.055
# 58         Honda         Accord             230.902               13.210
# ..           ...            ...                 ...                  ...
# 125      Porsche  Carrera Coupe               1.280               60.625
# 108   Oldsmobile        Cutlass               1.112               11.240
# 99    Mercedes-B          CL500               0.954                  NaN
# 39         Dodge          Viper               0.916               58.470
# 83    Mitsubishi         3000GT               0.110               20.940
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
car.sort_values(by=["Vehicle_type","Sales_in_thousands"], ascending=False)
# Out:
#     Manufacturer         Model  Sales_in_thousands  __year_resale_value  \
# 137       Toyota         Camry             247.994               13.245
# 49          Ford        Taurus             245.815               10.055
# 58         Honda        Accord             230.902               13.210
# 57         Honda         Civic             199.685                9.850
# 50          Ford         Focus             175.670                  NaN
# ..           ...           ...                 ...                  ...
# 18      Cadillac      Escalade              14.785                  NaN
# 60         Honda      Passport              12.855               17.525
# 84    Mitsubishi       Montero              11.337               19.125
# 144       Toyota  Land Cruiser               9.835               34.080
# 74         Lexus         LX470               9.126                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
car.sort_values(by=["Manufacturer","Sales_in_thousands"], ascending=[False, True])
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 155        Volvo      C70               3.493                  NaN
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 151        Volvo      S40              16.957                  NaN
# 154        Volvo      V70              17.531                  NaN
# ..           ...      ...                 ...                  ...
# 4           Audi       A4              20.397               22.255
# 3          Acura       RL               8.588               29.725
# 2          Acura       CL              14.114               18.225
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 155    Passenger                45.5          2.3       236.0      104.9
# ...

# %% [markdown]
# #### Dropping Columns

# %%
car.drop(columns=["newcol1", "newcol2", "Area_car"], inplace=True)

# %%
car.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor', 'Car_cat',
#        'Sale_cat'],
#       dtype='object')

# %%
car.drop(["Car_cat", "Sale_cat"], axis=1,inplace=True) # axis=1 ( columns operation), axis=0( Row operation)

# %%
car.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %% [markdown]
# #### Missing Value

# %%
car["__year_resale_value"].isnull().sum()
# Out:
# 38

# %%
car.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    38
# Vehicle_type            0
# Price_in_thousands      5
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
~car["Fuel_efficiency"].notnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# Name: Fuel_efficiency, Length: 157, dtype: bool

# %%
car[~car["Fuel_efficiency"].notnull()]
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 33      Chrysler  Town & Country              53.480               19.540
# 38         Dodge        Intrepid              88.028               12.275
# 109   Oldsmobile        Intrigue              38.554                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 33           Car                 NaN          NaN         NaN        NaN
# 38     Passenger              22.505          2.7       202.0      113.0
# 109    Passenger              24.150          3.5       215.0      109.0
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 33     NaN     NaN          NaN            NaN              NaN     7/13/2011
# 38    74.7   203.7        3.489           17.0              NaN    06-02-2012
# 109   73.6   195.9        3.455           18.0              NaN    04-01-2011
#
#      Power_perf_factor
# 33                 NaN
# ...

# %%
car_not_missing=car.dropna()

# %%
car_not_missing.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# dtype: int64

# %%
car.fillna(value=999)
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545              999.000
# 153        Volvo      S70              15.245              999.000
# 154        Volvo      V70              17.531              999.000
# 155        Volvo      C70               3.493              999.000
# 156        Volvo      S80              18.969              999.000
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger                21.5          1.8       140.0      101.2
# ...

# %%
car.fillna(method="ffill")
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545               13.760
# 153        Volvo      S70              15.245               13.760
# 154        Volvo      V70              17.531               13.760
# 155        Volvo      C70               3.493               13.760
# 156        Volvo      S80              18.969               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger                21.5          1.8       140.0      101.2
# ...

# %%
car.fillna(method="bfill")
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger                21.5          1.8       140.0      101.2
# ...

# %%
car["__year_resale_value"].fillna(value=car["__year_resale_value"].mean())
# Out:
# 0      16.36000
# 1      19.87500
# 2      18.22500
# 3      29.72500
# 4      22.25500
#          ...
# 152    17.85105
# 153    17.85105
# 154    17.85105
# 155    17.85105
# 156    17.85105
# Name: __year_resale_value, Length: 157, dtype: float64

# %%
car.fillna(value=car.mean())
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919             16.36000
# 1          Acura       TL              39.384             19.87500
# 2          Acura       CL              14.114             18.22500
# 3          Acura       RL               8.588             29.72500
# 4           Audi       A4              20.397             22.25500
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545             17.85105
# 153        Volvo      S70              15.245             17.85105
# 154        Volvo      V70              17.531             17.85105
# 155        Volvo      C70               3.493             17.85105
# 156        Volvo      S80              18.969             17.85105
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger           21.500000          1.8       140.0      101.2
# ...

# %% [markdown]
# ### Duplicates

# %%
car.duplicated().sum()
# Out:
# 0

# %%
car.drop_duplicates()

# %% [markdown]
# ### Statistics of data

# %%
car["Sales_in_thousands"].mean()
# Out:
# 52.99807643312102

# %%
car["Manufacturer"].mode()
# Out:
# 0    Dodge
# 1     Ford
# dtype: object

# %%
car["Vehicle_type"].mode()
# Out:
# 0    Passenger
# dtype: object

# %%
car["Vehicle_type"].value_counts()
# Out:
# Passenger    116
# Car           41
# Name: Vehicle_type, dtype: int64

# %%
car["Sales_in_thousands"].skew()
# Out:
# 3.408518366470572

# %%
car["Sales_in_thousands"].kurtosis()
# Out:
# 17.55734423299965

# %%
car.describe().T  # Only for Numerical Data
# Out:
#                      count        mean        std         min         25%  \
# Sales_in_thousands   157.0   52.998076  68.029422    0.110000   14.114000
# __year_resale_value  119.0   17.851050  11.374871    5.160000   11.250000
# Price_in_thousands   152.0   27.273862  14.431679    9.235000   17.888750
# Engine_size          156.0    3.060897   1.044653    1.000000    2.300000
# Horsepower           156.0  185.948718  56.700321   55.000000  149.500000
# Wheelbase            156.0  107.487179   7.641303   92.600000  103.000000
# Width                156.0   71.150000   3.451872   62.600000   68.400000
# Length               156.0  187.343590  13.431754  149.400000  177.575000
# Curb_weight          155.0    3.378026   0.630502    1.895000    2.971000
# Fuel_capacity        156.0   17.951923   3.887921   10.300000   15.800000
# Fuel_efficiency      154.0   23.844156   4.282706   15.000000   21.000000
# Power_perf_factor    155.0   77.043591  25.142664   23.276272   60.407707
#
# ...

# %%
# count, central tendacy, var, range, percentile

# %%
car.describe( include=["object"])
# Out:
#        Manufacturer Model Vehicle_type Latest_Launch
# count           157   157          157           157
# unique           30   156            2           130
# top           Dodge  Neon    Passenger     9/21/2011
# freq             11     2          116             2

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  119 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   152 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
car.describe( include=["object", "float64"]).T
# Out:
#                     count unique        top freq     mean       std      min  \
# Manufacturer          157     30      Dodge   11      NaN       NaN      NaN
# Model                 157    156       Neon    2      NaN       NaN      NaN
# Sales_in_thousands    157    NaN        NaN  NaN  52.9981   68.0294     0.11
# __year_resale_value   119    NaN        NaN  NaN  17.8511   11.3749     5.16
# Vehicle_type          157      2  Passenger  116      NaN       NaN      NaN
# Price_in_thousands    152    NaN        NaN  NaN  27.2739   14.4317    9.235
# Engine_size           156    NaN        NaN  NaN   3.0609   1.04465        1
# Horsepower            156    NaN        NaN  NaN  185.949   56.7003       55
# Wheelbase             156    NaN        NaN  NaN  107.487    7.6413     92.6
# Width                 156    NaN        NaN  NaN    71.15   3.45187     62.6
# Length                156    NaN        NaN  NaN  187.344   13.4318    149.4
# ...

# %%
basic_summ=car.describe(percentiles=[0.01, .02, .03, .04, .05, .1, .15, .25, .50, .75, .90, .95, .96,.97, .98, .99]).T

# %%
os.getcwd()
# Out:
# 'D:\\Training\\Imarticus\\PGA\\PGA15\\week3'

# %%
basic_summ.to_csv(r"D:\Training\Imarticus\PGA\PGA15\week4\basic_stat.csv")

# %%
basic_summ.to_excel("basic_stat.xlsx")

# %% [markdown]
# ### Renaming of columns

# %%
car.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
car2=car.rename(columns={"__year_resale_value":"Resale_value_After_4_year"})
# data.rename(columns={"Old_name1":"New_Name1", "Old_Name1":"New_Name1"})

# %%
car2.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands',
#        'Resale_value_After_4_year', 'Vehicle_type', 'Price_in_thousands',
#        'Engine_size', 'Horsepower', 'Wheelbase', 'Width', 'Length',
#        'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency', 'Latest_Launch',
#        'Power_perf_factor'],
#       dtype='object')

# %%
car4=car.rename(columns={"__year_resale_value":"Resale_value_After_4_year","Manufacturer":"Maker", "Fuel_efficiency":"Efficiency_of_Vehicle"})

# %%
car4.columns
# Out:
# Index(['Maker', 'Model', 'Sales_in_thousands', 'Resale_value_After_4_year',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Efficiency_of_Vehicle', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %% [markdown]
# ### Summary ( Group by )

# %%
car.groupby(["Manufacturer", "Vehicle_type"])["__year_resale_value", "Sales_in_thousands"].sum()
# Out:
# <ipython-input-177-6689f5dc67b1>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   car.groupby(["Manufacturer", "Vehicle_type"])["__year_resale_value", "Sales_in_thousands"].sum()
#                            __year_resale_value  Sales_in_thousands
# Manufacturer Vehicle_type
# Acura        Passenger                  84.185              79.005
# Audi         Passenger                  22.255              40.557
# BMW          Passenger                  64.800              46.505
# Buick        Passenger                  59.765             242.019
# Cadillac     Car                         0.000              14.785
#              Passenger                  93.575              97.393
# Chevrolet    Passenger                 105.845             554.365
# Chrysler     Car                        19.540              53.480
#              Passenger                  70.230             148.241
# ...

# %%
car.groupby(["Manufacturer"]).agg({"Sales_in_thousands":["min", "max", "sum", "mean","count"]})
# Out:
#              Sales_in_thousands
#                             min      max       sum        mean count
# Manufacturer
# Acura                     8.588   39.384    79.005   19.751250     4
# Audi                      1.380   20.397    40.557   13.519000     3
# BMW                       9.231   19.747    46.505   15.501667     3
# Buick                    27.851   91.561   242.019   60.504750     4
# Cadillac                  6.536   63.729   112.178   22.435600     5
# Chevrolet                17.947  145.519   554.365   61.596111     9
# Chrysler                  7.854   53.480   201.721   28.817286     7
# Dodge                     0.916  227.061   910.149   82.740818    11
# Ford                     35.068  540.561  2022.635  183.875909    11
# Honda                    12.855  230.902   592.674  118.534800     5
# Hyundai                  29.450   66.692   137.326   45.775333     3
# Infiniti                 23.713   23.713    23.713   23.713000     1
# ...

# %%
grp_summ=car.groupby(["Manufacturer"]).agg({"Sales_in_thousands":["min", "max", "sum", "mean","count"],
                                  "Price_in_thousands":["min", "max", "std"]})

# %%
grp_summ.to_excel("grp_summ.xlsx")

# %%
TabA=pd.DataFrame({"Id":[101, 102, 103, 104, 105],
             "Name":["A", "B", "C", "D", "E"]})

# %%
TabB=pd.DataFrame({"Id":[101, 102, 101, 102, 101, 103, 105, 109, 101],
             "address":["Delhi", "Noida", "Noida", "Mumbai", "Goa", "Noida","Gurugram", 
                        "Ghaziabad","GB"]})

# %%
Tab_inner=pd.merge(TabA, TabB, on=["Id"], how="inner")
# Out:
#     Id Name   address
# 0  101    A     Delhi
# 1  101    A     Noida
# 2  101    A       Goa
# 3  101    A        GB
# 4  102    B     Noida
# 5  102    B    Mumbai
# 6  103    C     Noida
# 7  105    E  Gurugram

# %%
Tab_left=pd.merge(TabA, TabB, on=["Id"], how="left")
Tab_left
# Out:
#     Id Name   address
# 0  101    A     Delhi
# 1  101    A     Noida
# 2  101    A       Goa
# 3  101    A        GB
# 4  102    B     Noida
# 5  102    B    Mumbai
# 6  103    C     Noida
# 7  104    D       NaN
# 8  105    E  Gurugram

# %%
Tab_left=pd.merge(TabA, TabB, on=["Id"], how="right")
Tab_left
# Out:
#     Id Name    address
# 0  101    A      Delhi
# 1  101    A      Noida
# 2  101    A        Goa
# 3  101    A         GB
# 4  102    B      Noida
# 5  102    B     Mumbai
# 6  103    C      Noida
# 7  105    E   Gurugram
# 8  109  NaN  Ghaziabad

# %%
Tab_left=pd.merge(TabA, TabB, on=["Id"], how="outer")
Tab_left
# Out:
#     Id Name    address
# 0  101    A      Delhi
# 1  101    A      Noida
# 2  101    A        Goa
# 3  101    A         GB
# 4  102    B      Noida
# 5  102    B     Mumbai
# 6  103    C      Noida
# 7  104    D        NaN
# 8  105    E   Gurugram
# 9  109  NaN  Ghaziabad

# %%
# pd.concat()
# pd.pivot()

# %%
grp_summ.columns
# Out:
# MultiIndex([('Sales_in_thousands',   'min'),
#             ('Sales_in_thousands',   'max'),
#             ('Sales_in_thousands',   'sum'),
#             ('Sales_in_thousands',  'mean'),
#             ('Sales_in_thousands', 'count'),
#             ('Price_in_thousands',   'min'),
#             ('Price_in_thousands',   'max'),
#             ('Price_in_thousands',   'std')],
#            )

# %%
TabA.columns=["Cust_id", "Name_cust"]

# %%
TabA
# Out:
#    Cust_id Name_cust
# 0      101         A
# 1      102         B
# 2      103         C
# 3      104         D
# 4      105         E

# %%
grp_summ1=grp_summ.copy()

# %%
new_col=[]
for i in grp_summ1.columns:
    new_col.append("_".join(i))
#     print("_".join(i))

# %%
new_col
# Out:
# ['Sales_in_thousands_min',
#  'Sales_in_thousands_max',
#  'Sales_in_thousands_sum',
#  'Sales_in_thousands_mean',
#  'Sales_in_thousands_count',
#  'Price_in_thousands_min',
#  'Price_in_thousands_max',
#  'Price_in_thousands_std']

# %%
grp_summ1.columns=new_col

# %%
grp_summ1
# Out:
#               Sales_in_thousands_min  Sales_in_thousands_max  \
# Manufacturer
# Acura                          8.588                  39.384
# Audi                           1.380                  20.397
# BMW                            9.231                  19.747
# Buick                         27.851                  91.561
# Cadillac                       6.536                  63.729
# Chevrolet                     17.947                 145.519
# Chrysler                       7.854                  53.480
# Dodge                          0.916                 227.061
# Ford                          35.068                 540.561
# Honda                         12.855                 230.902
# Hyundai                       29.450                  66.692
# Infiniti                      23.713                  23.713
# Jaguar                        15.467                  15.467
# Jeep                          55.557                 157.040
# ...
